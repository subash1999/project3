# %%
import os,sys
import time
import numpy as np
import pandas as pd

# %%
from sklearn.feature_selection import SelectKBest, SelectPercentile, SelectFdr, SelectFpr, SelectFwe
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import RFE,RFECV
from sklearn.feature_selection import chi2,f_classif, mutual_info_classif
from sklearn.model_selection import ParameterGrid, GridSearchCV
from sklearn.svm import LinearSVC, NuSVC, SVC
from sklearn.linear_model import LogisticRegression,LassoCV, Lasso
from sklearn.ensemble import ExtraTreesClassifier, BaggingClassifier, VotingClassifier, RandomForestClassifier
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA, NMF
# from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB, ComplementNB, BernoulliNB
from sklearn.metrics import  accuracy_score,auc,average_precision_score,roc_auc_score, recall_score,f1_score, log_loss, fbeta_score, confusion_matrix
from xgboost import XGBClassifier
from tpot import TPOTClassifier
from ReliefF import ReliefF
import seaborn as sns
from sklearn.utils import resample
from imblearn.over_sampling import SMOTE,SMOTENC,ADASYN, BorderlineSMOTE, KMeansSMOTE, SVMSMOTE,RandomOverSampler
from imblearn.combine import SMOTETomek, SMOTEENN
from sklearn.preprocessing import Normalizer,normalize
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, ExtraTreeClassifier
from sklearn.ensemble import AdaBoostClassifier,BaggingClassifier,ExtraTreesClassifier,GradientBoostingClassifier,StackingClassifier,VotingClassifier
from sklearn.feature_selection import SelectKBest, chi2, f_classif, mutual_info_classif
from sklearn.linear_model import RidgeClassifier
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.naive_bayes import BernoulliNB, ComplementNB, MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import NearestCentroid
from sklearn.ensemble import RandomForestClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
import pickle
# Out:
# Using TensorFlow backend.

# %%
from preprocessing.Normalize import Normalize
import helper.SeriesHelper as series_helper

# %%
X_train,X_test,y_train,y_test = Normalize().get_train_test()

# %%
train = {}
test = {}
for i in range(1,1001,1):
    # model = ReliefF(n_neighbors=100, n_features_to_keep=i)
    # model.fit(X_train,y_train)
    # model = SelectFromModel(LinearSVC()).fit(X_train,y_train)
    model = SelectKBest(k=i).fit(X_train,y_train)
    temp_train = model.transform(X_train)
    temp_test = model.transform(X_test)
    # model = SelectFromModel(DecisionTreeClassifier())
    # temp_train = model.transform(temp_X_train)
    # temp_test = model.transform(temp_X_test)
    learner = LogisticRegression(solver='liblinear',max_iter=10000).fit(temp_train,y_train)
    pred_train = learner.predict(temp_train)
    pred_test = learner.predict(temp_test) 
    train[i] = [accuracy_score(y_train,pred_train),average_precision_score(y_train,pred_train),roc_auc_score(y_train,pred_train),recall_score(y_train,pred_train),f1_score(y_train,pred_train)]   
    test[i] = [accuracy_score(y_test,pred_test),average_precision_score(y_test,pred_test),roc_auc_score(y_test,pred_test), recall_score(y_test,pred_test), f1_score(y_test,pred_test)] 
    print("Done ",i)
# Out:
# Done  1
# Done  2
# Done  3
# Done  4
# Done  5
# Done  6
# Done  7
# Done  8
# Done  9
# Done  10
# Done  11
# Done  12
# Done  13
# Done  14
# Done  15
# Done  16
# Done  17
# Done  18
# Done  19
# Done  20
# Done  21
# Done  22
# Done  23
# Done  24
# Done  25
# Done  26
# Done  27
# Done  28
# Done  29
# Done  30
# Done  31
# Done  32
# Done  33
# Done  34
# Done  35
# Done  36
# Done  37
# Done  38
# Done  39
# Done  40
# Done  41
# Done  42
# Done  43
# Done  44
# Done  45
# Done  46
# Done  47
# Done  48
# Done  49
# Done  50
# Done  51
# Done  52
# Done  53
# Done  54
# Done  55
# Done  56
# Done  57
# Done  58
# Done  59
# Done  60
# Done  61
# Done  62
# Done  63
# Done  64
# Done  65
# Done  66
# Done  67
# Done  68
# Done  69
# Done  70
# Done  71
# Done  72
# Done  73
# Done  74
# Done  75
# Done  76
# Done  77
# Done  78
# Done  79
# Done  80
# Done  836
# Done  837
# Done  838
# Done  839
# Done  840
# Done  841
# Done  842
# Done  843
# Done  844
# Done  845
# Done  846
# Done  847
# Done  848
# Done  849
# Done  850
# Done  851
# Done  852
# Done  853
# Done  854
# Done  855
# Done  856
# Done  857
# Done  858
# Done  859
# Done  860
# Done  861
# Done  862
# Done  863
# Done  864
# Done  865
# Done  866
# Done  867
# Done  868
# Done  869
# Done  870
# Done  871
# Done  872
# Done  873
# Done  874
# Done  875
# Done  876
# Done  877
# Done  878
# Done  879
# Done  880
# Done  881
# Done  882
# Done  883
# Done  884
# Done  885
# Done  886
# Done  887
# Done  888
# Done  889
# Done  890
# Done  891
# Done  892
# Done  893
# Done  894
# Done  895
# Done  896
# Done  897
# Done  898
# Done  899
# Done  900
# Done  901
# Done  902
# Done  903
# Done  904
# Done  905
# Done  906
# Done  907
# Done  908
# Done  909
# Done  910
# Done  911
# Done  912
# Done  913
# Done  914
# Done  915
# Done  916
# Done  917
# Done  918
# Done  919
# Done  920
# Done  921
# Done  922
# Done  923
# Done  924
# Done  925
# Done  926
# Done  927
# Done  928
# Done  929
# Done  930
# Done  931
# Done  932
# Done  933
# Done  934
# Done  935
# Done  936
# Done  937
# Done  938
# Done  939
# Done  940
# Done  941
# Done  942
# Done  943
# Done  944
# Done  945
# Done  946
# Done  947
# Done  948
# Done  949
# Done  950
# Done  951
# Done  952
# Done  953
# Done  954
# Done  955
# Done  956
# Done  957
# Done  958
# Done  959
# Done  960
# Done  961
# Done  962
# Done  963
# Done  964
# Done  965
# Done  966
# Done  967
# Done  968
# Done  969
# Done  970
# Done  971
# Done  972
# Done  973
# Done  974
# Done  975
# Done  976
# Done  977
# Done  978
# Done  979
# Done  980
# Done  981
# Done  982
# Done  983
# Done  984
# Done  985
# Done  986
# Done  987
# Done  988
# Done  989
# Done  990
# Done  991
# Done  992
# Done  993
# Done  994
# Done  995
# Done  996
# Done  997
# Done  998
# Done  999
# Done  1000

# %%
import matplotlib.pyplot as plt

# %%
train_df = pd.DataFrame({
    'selected_genes' : [x for x in list(train.keys())],
    'accuracy' : [train[x][0] for x in list(train.keys())],
    'precision' : [train[x][1] for x in list(train.keys())],
    'auc' : [train[x][2] for x in list(train.keys())],
    'recall_score' : [train[x][3] for x in list(train.keys())],
    'f1_score' : [train[x][4] for x in list(train.keys())],
})
train_df.sort_values(by=['f1_score','precision','recall_score','auc','accuracy'], ascending=False)[train_df['selected_genes'] == 859]
# Out:
#      selected_genes  accuracy  precision       auc  recall_score  f1_score
# 858             859  0.905615   0.818659  0.878239      0.780731  0.856102

# %%
test_df = pd.DataFrame({
    'selected_genes' : [x for x in list(test.keys())],
    'accuracy' : [test[x][0] for x in list(test.keys())],
    'precision' : [test[x][1] for x in list(test.keys())],
    'auc' : [test[x][2] for x in list(test.keys())],
    'recall_score' : [test[x][3] for x in list(test.keys())],
    'f1_score' : [test[x][4] for x in list(test.keys())],
})
test_df.sort_values(by=['f1_score','precision','recall_score','auc','accuracy'], ascending=False)
# 12               13  0.666667   0.408787  0.556856      0.161538  0.259259
# 47               48  0.627778   0.378607  0.529766      0.176923  0.255556
# 11               12  0.661111   0.400897  0.549164      0.146154  0.237500
# 5                 6  0.658333   0.396225  0.543645      0.130769  0.216561
# 6                 7  0.655556   0.393284  0.541472      0.130769  0.215190
# 7                 8  0.652778   0.390547  0.539298      0.130769  0.213836
# 8                 9  0.652778   0.390547  0.539298      0.130769  0.213836
# 10               11  0.652778   0.389601  0.537625      0.123077  0.203822
# 9                10  0.650000   0.386996  0.535452      0.123077  0.202532
# 3                 4  0.652778   0.388675  0.535953      0.115385  0.193548
# 2                 3  0.650000   0.386012  0.533779      0.115385  0.192308
# 4                 5  0.641667   0.377000  0.523913      0.100000  0.167742
# 1                 2  0.644444   0.375053  0.519398      0.069231  0.123288
# 0                 1  0.638889   0.364316  0.505017      0.023077  0.044118
#
# [1000 rows x 6 columns]

# %%
plt.plot('selected_genes','accuracy',data=train_df,markerfacecolor='blue',markersize=12,color='skyblue',linewidth=4)
plt.plot('selected_genes','precision',data=train_df,color='olive',linewidth=2)
plt.plot('selected_genes','auc',data=train_df,color='blue',linewidth=2, linestyle='dashed',label='toto')
plt.plot('selected_genes','recall_score',data=train_df,color='green',linewidth=2)
plt.plot('selected_genes','f1_score',data=train_df,color='green',linewidth=2)
plt.legend()

# %%
plt.plot('selected_genes','accuracy',data=test_df,markerfacecolor='blue',markersize=12,color='skyblue',linewidth=1)
plt.plot('selected_genes','precision',data=test_df,color='olive',linewidth=1)
plt.plot('selected_genes','auc',data=test_df,color='blue',linewidth=1)
plt.plot('selected_genes','recall_score',data=test_df,color='green',linewidth=2)
plt.plot('selected_genes','f1_score',data=test_df,color='green',linewidth=2)
plt.legend()

# %%
temp_X_train, temp_y_train = X_train,y_train
temp_X_test = X_test
temp_y_test = y_test

# smote = SMOTE(random_state=27,k_neighbors=30,n_jobs=5)
# temp_X_train, temp_y_train = smote.fit_sample(X_train, y_train)
# temp_X_test = X_test

# smoteenn = SMOTEENN(n_jobs=6)
# temp_X_train, temp_y_train = smoteenn.fit_sample(X_train, y_train)
# temp_X_test = X_test

# smotetomek = SMOTETomek(n_jobs=6)
# temp_X_train, temp_y_train = smotetomek.fit_sample(X_train, y_train)
# temp_X_test = X_test

# Boderline is the best until now
borderline = BorderlineSMOTE(random_state=27,k_neighbors=30,n_jobs=5,m_neighbors=10)
temp_X_train, temp_y_train = borderline.fit_sample(X_train, y_train)
temp_X_test = X_test

# kmeans = KMeansSMOTE(random_state=27,k_neighbors=20,n_jobs=5)
# temp_X_train, temp_y_train = kmeans.fit_sample(X_train, y_train)
# temp_X_test = X_test

# svm = SVMSMOTE(random_state=27,k_neighbors=30,n_jobs=6,m_neighbors=30)
# temp_X_train, temp_y_train = svm.fit_sample(X_train, y_train)
# temp_X_test = X_test

# smotenc = SMOTENC(categorical_features=list(np.arange(1,100)),random_state=27,n_jobs=5)
# temp_X_train, temp_y_train = smotenc.fit_sample(X_train, y_train)
# temp_X_test = X_test

# adasyn = ADASYN(random_state=27)
# temp_X_train, temp_y_train = adasyn.fit_sample(X_train, y_train)
# temp_X_test = X_test

# random  = RandomOverSampler(random_state=27)
# temp_X_train, temp_y_train = random.fit_sample(X_train, y_train)
# temp_X_test = X_test

std_scale = normalize(temp_X_train)
temp_X_train = normalize(temp_X_train)
temp_X_test = normalize(temp_X_test)

best =  SelectKBest(score_func=f_classif ,k=860).fit(temp_X_train,temp_y_train)
temp_X_train = best.transform(temp_X_train)
temp_X_test = best.transform(temp_X_test)

# %%
temp_X_train.shape,X_train.shape,temp_X_test.shape,X_test.shape
# Out:
# ((1072, 860), (837, 11035), (360, 860), (360, 11035))

# %%
# nmf = NMF(n_components=300).fit(temp_X_train,temp_y_train)
# temp_X_train = nmf.transform(temp_X_train)
# temp_X_test = nmf.transform(temp_X_test)

# %%
# best =  SelectKBest(k=100).fit(temp_X_train,temp_y_train)
# temp_X_train = best.transform(temp_X_train)
# temp_X_test = best.transform(temp_X_test)

# %%
# model = SelectFromModel(LogisticRegression(solver='liblinear')).fit(temp_X_train,temp_y_train)
# model = SelectFromModel(ExtraTreeClassifier()).fit(temp_X_train,temp_y_train)
# temp_X_train = model.transform(temp_X_train)
# temp_X_test = model.transform(temp_X_test)

# %%
temp_X_train.shape
# Out:
# (1072, 860)

# %%
select_from_models = {'dtc' : DecisionTreeClassifier(),
                        'etc' : ExtraTreeClassifier(),
                        'lr_elasticnet' : LogisticRegression(solver='saga',penalty='elasticnet',l1_ratio=0.7),
                        'lr_l1' : LogisticRegression(solver='liblinear', penalty='l1',max_iter=10000),
                        'lr_l2' : LogisticRegression(solver='liblinear',penalty='l2'),
                        'lr' : LogisticRegression(),
                        'lsvc' : LinearSVC(),
                        'rfc' : RandomForestClassifier(),
                        'sgd' : SGDClassifier(penalty='elasticnet'),
                        'lcv' : LassoCV(),
                        'lda' : LinearDiscriminantAnalysis(),
                        }
for penalty in ["l2", "l1"]:
    # Train Liblinear model
    select_from_models['lsvc_'+str(penalty)] = LinearSVC(penalty=penalty, dual=False,tol=1e-3)
    # Train SGD model
    select_from_models['sgd_'+str(penalty)] = SGDClassifier(alpha=.0001, max_iter=100,penalty=penalty)

# %%
models = {}

models['lr_liblinear'] = LogisticRegression(solver='liblinear')
models['lsvc']  = LinearSVC()
models['lr'] = LogisticRegression()
models['lr_elasticnet'] = LogisticRegression(solver='saga',penalty='elasticnet',l1_ratio=0.7)
models['lr_l1'] = LogisticRegression(solver='liblinear', penalty='l1')
models['lr_l2'] = LogisticRegression(solver='liblinear',penalty='l2')
models['dtc'] = DecisionTreeClassifier()
models['etc'] = ExtraTreeClassifier()
models['svc'] = SVC(probability=True)
models['rfc'] = RandomForestClassifier()
models['ridge'] = RidgeClassifier()
models['perceptron'] = Perceptron()
models['passive_aggressive_classifier'] = PassiveAggressiveClassifier()
models['nc'] = NearestCentroid()
models['lda'] = LinearDiscriminantAnalysis()
models['sgd_elasticnet'] = SGDClassifier(alpha=.0001, max_iter=100,penalty="elasticnet", loss="modified_huber")

for n in range(1,101):
    models['knn_'+str(n)] = KNeighborsClassifier(n_neighbors=n,n_jobs=6)


for penalty in ["l2", "l1"]:
    # Train Liblinear model
    models['lsvc_'+str(penalty)] = LinearSVC(penalty=penalty, dual=False,tol=1e-3)
    # Train SGD model
    models['sgd_'+str(penalty)] = SGDClassifier(alpha=.0001, max_iter=100,penalty=penalty,loss="modified_huber")

temp = {'dtc' : DecisionTreeClassifier(max_depth=10),'etc' : ExtraTreeClassifier(),'svc': SVC()}
for x in temp.keys():
    models['adaboost_'+x] = AdaBoostClassifier(base_estimator=temp[x],algorithm='SAMME')
models['mnb'] = MultinomialNB()
models['bnb'] = BernoulliNB()
models['cnb'] = ComplementNB()

# %%
def prediction(model,X_test,y_test):
    y_pred = np.abs(np.round(model.predict(X_test)))
    l = []
    try:
        tn, fp, fn, tp = confusion_matrix(y_test,y_pred).ravel()
        l.append([[tp,fp],[fn,tn]])
        l.append(average_precision_score(y_test, y_pred))
        l.append(recall_score(y_test, y_pred))
        l.append(f1_score(y_test,y_pred))        
        l.append(fbeta_score(y_test, y_pred,average='weighted', beta=0.5))
        l.append(accuracy_score(y_test, y_pred))
        l.append(log_loss(y_test, y_pred))
        l.append(roc_auc_score(y_test,y_pred))
    except Exception as e:
        print(e)
        print(model,"\n\n",y_pred)

    return l

# %%
df_result_cols = ['model_dict_name','model_name','selectfrommodel_name','selectfrommodel','confusion','precision','recall_score','f1_score','fbeta_score','accuracy','log_loss','roc_auc_score']
df_result_rows = []
from scikitplot.metrics import plot_precision_recall
for sfm_k in select_from_models.keys():
    selectfrommodel = SelectFromModel(select_from_models[sfm_k]).fit(temp_X_train,temp_y_train)
    _X_train = selectfrommodel.transform(temp_X_train)
    _X_test = selectfrommodel.transform(temp_X_test)
    if(_X_train.shape[1]>0 and _X_test.shape[1]>0):
        for m_k in models.keys():               
                models[m_k] = models[m_k].fit(_X_train,temp_y_train)
                df_result_rows.append( [m_k,models[m_k],sfm_k,select_from_models[sfm_k]] +
                                        prediction(models[m_k],_X_test,y_test) )
    else:
        print([sfm_k,select_from_models[sfm_k]])
        print('--------------'*5,'\n','--------------'*5)
# Out:
# ['lr_l1', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=10000,
#                    multi_class='auto', n_jobs=None, penalty='l1',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)]
# ----------------------------------------------------------------------
#  ----------------------------------------------------------------------

# %%
sort_by = ['f1_score','precision','recall_score','fbeta_score','log_loss','accuracy','roc_auc_score']
df = pd.DataFrame(data = df_result_rows,columns=df_result_cols).sort_values(by=sort_by,ascending=False)
# set(list(df[0:1000]['model_dict_name']))
df
# Out:
#                     model_dict_name  \
# 1184                         knn_35
# 776                           knn_5
# 1186                         knn_37
# 1185                         knn_36
# 1042                         knn_19
# 20                            knn_5
# 801                          knn_30
# 294                          knn_27
# 1044                         knn_21
# 30                           knn_15
# 300                          knn_33
# 1673                         knn_20
# 1682                         knn_29
# 26                           knn_11
# 1671                         knn_18
# 977                          knn_80
# 1402                          knn_1
# 806                          knn_35
# 1040                         knn_17
# 781                          knn_10
# 1404                          knn_3
# 1687                         knn_34
# 281                          knn_14
# 667                          knn_22
# 802                          knn_31
# 1297                         knn_22
# 1036                         knn_13
# 1195                         knn_46
# 1198                         knn_49
# 668                          knn_23
# ...                             ...
# 1505                         sgd_l1
# 264   passive_aggressive_classifier
# 621                          sgd_l2
# 495                          sgd_l2
# 390   passive_aggressive_classifier
# 267                  sgd_elasticnet
# 393                  sgd_elasticnet
# 1149                 sgd_elasticnet
# 1650  passive_aggressive_classifier
# 3                     lr_elasticnet
# 4                             lr_l1
# 12    passive_aggressive_classifier
# 130                           lr_l1
# 141                  sgd_elasticnet
# 256                           lr_l1
# 381                   lr_elasticnet
# 382                           lr_l1
# 508                           lr_l1
# 633                   lr_elasticnet
# 634                           lr_l1
# 760                           lr_l1
# 886                           lr_l1
# 1012                          lr_l1
# 1138                          lr_l1
# 1264                          lr_l1
# 1390                          lr_l1
# 1515                  lr_elasticnet
# 1516                          lr_l1
# 1636                            bnb
# 1642                          lr_l1
#
#                                              model_name selectfrommodel_name  \
# 1184  KNeighborsClassifier(algorithm='auto', leaf_si...                  lda
# 776   KNeighborsClassifier(algorithm='auto', leaf_si...                  rfc
# 1186  KNeighborsClassifier(algorithm='auto', leaf_si...                  lda
# 1185  KNeighborsClassifier(algorithm='auto', leaf_si...                  lda
# 1042  KNeighborsClassifier(algorithm='auto', leaf_si...                  lcv
# 20    KNeighborsClassifier(algorithm='auto', leaf_si...                  dtc
# 801   KNeighborsClassifier(algorithm='auto', leaf_si...                  rfc
# 294   KNeighborsClassifier(algorithm='auto', leaf_si...        lr_elasticnet
# 1044  KNeighborsClassifier(algorithm='auto', leaf_si...                  lcv
# 30    KNeighborsClassifier(algorithm='auto', leaf_si...                  dtc
# 300   KNeighborsClassifier(algorithm='auto', leaf_si...        lr_elasticnet
# 1673  KNeighborsClassifier(algorithm='auto', leaf_si...               sgd_l1
# 1682  KNeighborsClassifier(algorithm='auto', leaf_si...               sgd_l1
# 26    KNeighborsClassifier(algorithm='auto', leaf_si...                  dtc
# 1671  KNeighborsClassifier(algorithm='auto', leaf_si...               sgd_l1
# 977   KNeighborsClassifier(algorithm='auto', leaf_si...                  sgd
# 1402  KNeighborsClassifier(algorithm='auto', leaf_si...               sgd_l2
# 806   KNeighborsClassifier(algorithm='auto', leaf_si...                  rfc
# 1040  KNeighborsClassifier(algorithm='auto', leaf_si...                  lcv
# 781   KNeighborsClassifier(algorithm='auto', leaf_si...                  rfc
# 1404  KNeighborsClassifier(algorithm='auto', leaf_si...               sgd_l2
# 1687  KNeighborsClassifier(algorithm='auto', leaf_si...               sgd_l1
# 281   KNeighborsClassifier(algorithm='auto', leaf_si...        lr_elasticnet
# 667   KNeighborsClassifier(algorithm='auto', leaf_si...                 lsvc
# 802   KNeighborsClassifier(algorithm='auto', leaf_si...                  rfc
# 1297  KNeighborsClassifier(algorithm='auto', leaf_si...              lsvc_l2
# 1036  KNeighborsClassifier(algorithm='auto', leaf_si...                  lcv
# 1195  KNeighborsClassifier(algorithm='auto', leaf_si...                  lda
# 1198  KNeighborsClassifier(algorithm='auto', leaf_si...                  lda
# 668   KNeighborsClassifier(algorithm='auto', leaf_si...                 lsvc
# ...                                                 ...                  ...
# 1505  SGDClassifier(alpha=0.0001, average=False, cla...               sgd_l2
# 264   PassiveAggressiveClassifier(C=1.0, average=Fal...        lr_elasticnet
# 621   SGDClassifier(alpha=0.0001, average=False, cla...                   lr
# 495   SGDClassifier(alpha=0.0001, average=False, cla...                lr_l2
# 390   PassiveAggressiveClassifier(C=1.0, average=Fal...                lr_l2
# 267   SGDClassifier(alpha=0.0001, average=False, cla...        lr_elasticnet
# 393   SGDClassifier(alpha=0.0001, average=False, cla...                lr_l2
# 1149  SGDClassifier(alpha=0.0001, average=False, cla...                  lda
# 1650  PassiveAggressiveClassifier(C=1.0, average=Fal...               sgd_l1
# 3     LogisticRegression(C=1.0, class_weight=None, d...                  dtc
# 4     LogisticRegression(C=1.0, class_weight=None, d...                  dtc
# 12    PassiveAggressiveClassifier(C=1.0, average=Fal...                  dtc
# 130   LogisticRegression(C=1.0, class_weight=None, d...                  etc
# 141   SGDClassifier(alpha=0.0001, average=False, cla...                  etc
# 256   LogisticRegression(C=1.0, class_weight=None, d...        lr_elasticnet
# 381   LogisticRegression(C=1.0, class_weight=None, d...                lr_l2
# 382   LogisticRegression(C=1.0, class_weight=None, d...                lr_l2
# 508   LogisticRegression(C=1.0, class_weight=None, d...                   lr
# 633   LogisticRegression(C=1.0, class_weight=None, d...                 lsvc
# 634   LogisticRegression(C=1.0, class_weight=None, d...                 lsvc
# 760   LogisticRegression(C=1.0, class_weight=None, d...                  rfc
# 886   LogisticRegression(C=1.0, class_weight=None, d...                  sgd
# 1012  LogisticRegression(C=1.0, class_weight=None, d...                  lcv
# 1138  LogisticRegression(C=1.0, class_weight=None, d...                  lda
# 1264  LogisticRegression(C=1.0, class_weight=None, d...              lsvc_l2
# 1390  LogisticRegression(C=1.0, class_weight=None, d...               sgd_l2
# 1515  LogisticRegression(C=1.0, class_weight=None, d...              lsvc_l1
# 1516  LogisticRegression(C=1.0, class_weight=None, d...              lsvc_l1
# 1636  BernoulliNB(alpha=1.0, binarize=0.0, class_pri...              lsvc_l1
# 1642  LogisticRegression(C=1.0, class_weight=None, d...               sgd_l1
#
#                                         selectfrommodel  \
# 1184  LinearDiscriminantAnalysis(n_components=None, ...
# 776   RandomForestClassifier(bootstrap=True, ccp_alp...
# 1186  LinearDiscriminantAnalysis(n_components=None, ...
# 1185  LinearDiscriminantAnalysis(n_components=None, ...
# 1042  LassoCV(alphas=None, copy_X=True, cv=None, eps...
# 20    DecisionTreeClassifier(ccp_alpha=0.0, class_we...
# 801   RandomForestClassifier(bootstrap=True, ccp_alp...
# 294   LogisticRegression(C=1.0, class_weight=None, d...
# 1044  LassoCV(alphas=None, copy_X=True, cv=None, eps...
# 30    DecisionTreeClassifier(ccp_alpha=0.0, class_we...
# 300   LogisticRegression(C=1.0, class_weight=None, d...
# 1673  SGDClassifier(alpha=0.0001, average=False, cla...
# 1682  SGDClassifier(alpha=0.0001, average=False, cla...
# 26    DecisionTreeClassifier(ccp_alpha=0.0, class_we...
# 1671  SGDClassifier(alpha=0.0001, average=False, cla...
# 977   SGDClassifier(alpha=0.0001, average=False, cla...
# 1402  SGDClassifier(alpha=0.0001, average=False, cla...
# 806   RandomForestClassifier(bootstrap=True, ccp_alp...
# 1040  LassoCV(alphas=None, copy_X=True, cv=None, eps...
# 781   RandomForestClassifier(bootstrap=True, ccp_alp...
# 1404  SGDClassifier(alpha=0.0001, average=False, cla...
# 1687  SGDClassifier(alpha=0.0001, average=False, cla...
# 281   LogisticRegression(C=1.0, class_weight=None, d...
# 667   LinearSVC(C=1.0, class_weight=None, dual=True,...
# 802   RandomForestClassifier(bootstrap=True, ccp_alp...
# 1297  LinearSVC(C=1.0, class_weight=None, dual=False...
# 1036  LassoCV(alphas=None, copy_X=True, cv=None, eps...
# 1195  LinearDiscriminantAnalysis(n_components=None, ...
# 1198  LinearDiscriminantAnalysis(n_components=None, ...
# 668   LinearSVC(C=1.0, class_weight=None, dual=True,...
# ...                                                 ...
# 1505  SGDClassifier(alpha=0.0001, average=False, cla...
# 264   LogisticRegression(C=1.0, class_weight=None, d...
# 621   LogisticRegression(C=1.0, class_weight=None, d...
# 495   LogisticRegression(C=1.0, class_weight=None, d...
# 390   LogisticRegression(C=1.0, class_weight=None, d...
# 267   LogisticRegression(C=1.0, class_weight=None, d...
# 393   LogisticRegression(C=1.0, class_weight=None, d...
# 1149  LinearDiscriminantAnalysis(n_components=None, ...
# 1650  SGDClassifier(alpha=0.0001, average=False, cla...
# 3     DecisionTreeClassifier(ccp_alpha=0.0, class_we...
# 4     DecisionTreeClassifier(ccp_alpha=0.0, class_we...
# 12    DecisionTreeClassifier(ccp_alpha=0.0, class_we...
# 130   ExtraTreeClassifier(ccp_alpha=0.0, class_weigh...
# 141   ExtraTreeClassifier(ccp_alpha=0.0, class_weigh...
# 256   LogisticRegression(C=1.0, class_weight=None, d...
# 381   LogisticRegression(C=1.0, class_weight=None, d...
# 382   LogisticRegression(C=1.0, class_weight=None, d...
# 508   LogisticRegression(C=1.0, class_weight=None, d...
# 633   LinearSVC(C=1.0, class_weight=None, dual=True,...
# 634   LinearSVC(C=1.0, class_weight=None, dual=True,...
# 760   RandomForestClassifier(bootstrap=True, ccp_alp...
# 886   SGDClassifier(alpha=0.0001, average=False, cla...
# 1012  LassoCV(alphas=None, copy_X=True, cv=None, eps...
# 1138  LinearDiscriminantAnalysis(n_components=None, ...
# 1264  LinearSVC(C=1.0, class_weight=None, dual=False...
# 1390  SGDClassifier(alpha=0.0001, average=False, cla...
# 1515  LinearSVC(C=1.0, class_weight=None, dual=False...
# 1516  LinearSVC(C=1.0, class_weight=None, dual=False...
# 1636  LinearSVC(C=1.0, class_weight=None, dual=False...
# 1642  SGDClassifier(alpha=0.0001, average=False, cla...
#
#                    confusion  precision  recall_score  f1_score  fbeta_score  \
# 1184   [[121, 181], [9, 49]]   0.397924      0.930769  0.560185     0.502087
# 776    [[126, 195], [4, 35]]   0.391557      0.969231  0.558758     0.450543
# 1186   [[121, 186], [9, 44]]   0.391850      0.930769  0.553776     0.478877
# 1185  [[118, 179], [12, 51]]   0.393965      0.907692  0.552693     0.499652
# 1042   [[126, 200], [4, 30]]   0.385722      0.969231  0.552632     0.420487
[0, 0], [130, 230]]   0.361111      0.000000  0.000000     0.439953
# 1642    [[0, 0], [130, 230]]   0.361111      0.000000  0.000000     0.439953
#
#       accuracy   log_loss  roc_auc_score
# 1184  0.472222  18.229201       0.571906
# 776   0.447222  19.092701       0.560702
# 1186  0.458333  18.708917       0.561037
# 1185  0.469444  18.325137       0.564716
# 1042  0.433333  19.572418       0.549833
# 20    0.525000  16.406243       0.586455
# 801   0.447222  19.092692       0.554013
# 294   0.433333  19.572415       0.548161
# 1044  0.433333  19.572415       0.548161
# 30    0.491667  17.557578       0.572074
# 300   0.441667  19.284581       0.551338
# 1673  0.441667  19.284581       0.551338
# 1682  0.441667  19.284581       0.551338
# 26    0.500000  17.269744       0.575251
# 1671  0.436111  19.476470       0.548662
# 977   0.472222  18.229190       0.563545
# 1402  0.472222  18.229190       0.563545
# 806   0.444444  19.188636       0.551839
# 1040  0.430556  19.668359       0.545987
# 781   0.452778  18.900801       0.555017
# 1404  0.452778  18.900801       0.555017
# 1687  0.452778  18.900801       0.555017
# 281   0.438889  19.380524       0.549164
# 667   0.441667  19.284579       0.549666
# 802   0.441667  19.284579       0.549666
# 1297  0.441667  19.284579       0.549666
# 1036  0.427778  19.764302       0.543813
# 1195  0.463889  18.517022       0.558696
# 1198  0.463889  18.517022       0.558696
# 668   0.436111  19.476468       0.546990
# ...        ...        ...            ...
# 1505  0.672222  11.321059       0.557860
# 264   0.669444  11.416998       0.552341
# 621   0.666667  11.512941       0.550167
# 495   0.658333  11.800753       0.530268
# 390   0.652778  11.992640       0.525920
# 267   0.655556  11.896694       0.526421
# 393   0.655556  11.896694       0.526421
# 1149  0.641667  12.376395       0.503846
# 1650  0.641667  12.376395       0.503846
# 3     0.638889  12.472336       0.500000
# 4     0.638889  12.472336       0.500000
# 12    0.638889  12.472336       0.500000
# 130   0.638889  12.472336       0.500000
# 141   0.638889  12.472336       0.500000
# 256   0.638889  12.472336       0.500000
# 381   0.638889  12.472336       0.500000
# 382   0.638889  12.472336       0.500000
# 508   0.638889  12.472336       0.500000
# 633   0.638889  12.472336       0.500000
# 634   0.638889  12.472336       0.500000
# 760   0.638889  12.472336       0.500000
# 886   0.638889  12.472336       0.500000
# 1012  0.638889  12.472336       0.500000
# 1138  0.638889  12.472336       0.500000
# 1264  0.638889  12.472336       0.500000
# 1390  0.638889  12.472336       0.500000
# 1515  0.638889  12.472336       0.500000
# 1516  0.638889  12.472336       0.500000
# 1636  0.638889  12.472336       0.500000
# 1642  0.638889  12.472336       0.500000
#
# [1764 rows x 12 columns]

# %%
a = []
b = []
for x in df.index:
    a.append(df.iloc[x]['model_dict_name'])
    b.append(df.iloc[x]['selectfrommodel_name'])
    # print(,"\t",)
for x in set(a):
    print(x)
print(set(b))

# %%
pipes = []
for x in df.index[0:20]:
    if df.iloc[x]['model_dict_name'] not in ['perceptron','ridge','passive_aggressive_classifier','lsvc','lsvc_l1','lsvc_l2','nc']:
        pipes.append(("p"+str(x),Pipeline([
            ['feature_selection',SelectFromModel(df.iloc[x]['selectfrommodel'])],
            ['model',df.iloc[x]['model_name']],
        ])))

# %%
v = VotingClassifier(estimators=[
    # ('perceptron',Perceptron()),
    ('etc',ExtraTreeClassifier()),
    ('dtc',DecisionTreeClassifier()),    
    ('lr',LogisticRegression()),
    ('svc', SVC(probability=True)),
    # ('lsvc',LinearSVC()),
    ('rfc',RandomForestClassifier()),
    ('mnb',MultinomialNB()),
],voting='soft')
v = v.fit(temp_X_train,temp_y_train)

# %%
prediction(v,temp_X_test,temp_y_test)
# Out:
# [[[57, 58], [73, 172]],
#  0.42010219249349684,
#  0.43846153846153846,
#  0.46530612244897956,
#  0.6285213459712689,
#  0.6361111111111111,
#  12.56840578995625,
#  0.5931438127090302]

# %%
ada = AdaBoostClassifier(base_estimator=ExtraTreeClassifier(),n_estimators=500,learning_rate=0.001,algorithm='SAMME.R')
ada = ada.fit(temp_X_train,temp_y_train)

# %%
prediction(ada,temp_X_test,temp_y_test)
# Out:
# [[[60, 97], [70, 133]],
#  0.3708285698731558,
#  0.46153846153846156,
#  0.4181184668989547,
#  0.5506561559052202,
#  0.5361111111111111,
#  16.02237005250226,
#  0.5198996655518395]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout
# from tensorflow.keras import optimizers
# m = 0
# m = Sequential()
# m.add(Dense(temp_X_train.shape[1],activation='relu',kernel_initializer='random_normal',input_dim=temp_X_train.shape[1]))
# m.add(Dense(int(temp_X_train.shape[1]/2),activation='relu', kernel_initializer='random_normal'))
# m.add(Dense(int(temp_X_train.shape[1]/4),activation='sigmoid', kernel_initializer='random_normal'))
# m.add(Dense(int(temp_X_train.shape[1]/8),activation='relu', kernel_initializer='random_normal'))
# m.add(Dense(1,activation='sigmoid', kernel_initializer='random_normal'))
# adam = optimizers.Adam(learning_rate=0.00001, beta_1=0.9, beta_2=0.999, amsgrad=False)
# m.compile(optimizer=adam,loss='binary_crossentropy',metrics=['accuracy','mse'])
# m.fit(temp_X_train,temp_y_train,validation_data=(temp_X_test,y_test),batch_size=5,epochs=200)

# %%
average_precision_score(temp_y_train,np.ceil(m.predict(temp_X_train)))
# Out:
# 0.5

# %%
average_precision_score(y_test,np.ceil(m.predict(temp_X_test)))
# Out:
# 0.32934131736526945

# %%
z = np.abs(stats.zscore(normal_matrix))
pd.DataFrame(z).find
# Out:
# (array([   0,    0,    0, ..., 1196, 1196, 1196], dtype=int64), array([    0,     1,     2, ..., 11032, 11033, 11034], dtype=int64))

# %%
normal_matrix.columns[0].shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1825-e867673b729d> in <module>
# ----> 1 normal_matrix.columns[0].shape
#
# AttributeError: 'str' object has no attribute 'shape'

# %% [markdown]
# # Use Bagging and Boosting, ensemble learning in future

# %%
knn = KNeighborsClassifier(n_neighbors=35,n_jobs=6)
select_from_model = SelectFromModel(LinearDiscriminantAnalysis())
feature_union = FeatureUnion([
    ('select_from_model',SelectFromModel(estimator=LinearDiscriminantAnalysis())),
    ('nmf',NMF(n_components=1))
])
pipes = Pipeline([
    ('feature_union',feature_union),
    ('model',KNeighborsClassifier(n_neighbors=35,n_jobs=6))
])

params = {
    'feature_union__select_from_model__estimator' : [LinearDiscriminantAnalysis(),ExtraTreeClassifier(),DecisionTreeClassifier(),RandomForestClassifier(),LinearSVC()],
    'feature_union__nmf__n_components':[i for i in range(1,101)],
    'model__n_neighbors':[i for i in range(20,50)]
}

grid = GridSearchCV(estimator=pipes,param_grid=params,scoring=['f1','recall','average_precision','precision','roc_auc'],n_jobs=6,verbose=1,refit='f1')

# %%
grid.fit(temp_X_train,temp_y_train)
# Out:
# Fitting 5 folds for each of 15000 candidates, totalling 75000 fits
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done  38 tasks      | elapsed:   37.3s
# [Parallel(n_jobs=6)]: Done 188 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=6)]: Done 438 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=6)]: Done 788 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=6)]: Done 1238 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=6)]: Done 1788 tasks      | elapsed: 15.9min
# [Parallel(n_jobs=6)]: Done 2438 tasks      | elapsed: 23.1min
# [Parallel(n_jobs=6)]: Done 3188 tasks      | elapsed: 30.9min
# [Parallel(n_jobs=6)]: Done 4038 tasks      | elapsed: 39.8min
# [Parallel(n_jobs=6)]: Done 4988 tasks      | elapsed: 52.0min
# [Parallel(n_jobs=6)]: Done 6038 tasks      | elapsed: 65.1min
# [Parallel(n_jobs=6)]: Done 7188 tasks      | elapsed: 79.4min
# [Parallel(n_jobs=6)]: Done 8438 tasks      | elapsed: 98.9min
# [Parallel(n_jobs=6)]: Done 9788 tasks      | elapsed: 118.5min
# [Parallel(n_jobs=6)]: Done 11238 tasks      | elapsed: 140.3min
# [Parallel(n_jobs=6)]: Done 12788 tasks      | elapsed: 170.2min
# [Parallel(n_jobs=6)]: Done 14438 tasks      | elapsed: 198.5min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-80c4d85ad171> in <module>
# ----> 1 grid.fit(temp_X_train,temp_y_train)
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     708                 return results
#     709
# --> 710             self._run_search(evaluate_candidates)
#     711
#     712         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1149     def _run_search(self, evaluate_candidates):
#    1150         """Search all candidates in param_grid"""
# -> 1151         evaluate_candidates(ParameterGrid(self.param_grid))
#    1152
#    1153
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params)
#     687                                for parameters, (train, test)
#     688                                in product(candidate_params,
# --> 689                                           cv.split(X, y, groups)))
#     690
#     691                 if len(out) < 1:
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#     932
#     933             with self._backend.retrieval_context():
# --> 934                 self.retrieve()
#     935             # Make sure that we get a last message telling us we are done
#     936             elapsed_time = time.time() - self._start_time
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\joblib\parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#     835                     self._output.extend(job.get())
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\joblib\_parallel_backends.py in wrap_future_result(future, timeout)
#     519         AsyncResults.get from multiprocessing."""
#     520         try:
# --> 521             return future.result(timeout=timeout)
#     522         except LokyTimeoutError:
#     523             raise TimeoutError()
#
# ~\AppData\Local\Programs\Python\Python36\lib\concurrent\futures\_base.py in result(self, timeout)
#     425                 return self.__get_result()
#     426
# --> 427             self._condition.wait(timeout)
#     428
#     429             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~\AppData\Local\Programs\Python\Python36\lib\threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %%
def load_pickle(filename):
    with open(filename+'.pickle', 'rb') as config_dictionary_file:
        return pickle.load(config_dictionary_file)

# %%
grid = load_pickle("grid_search_result_main4_")

# %%
grid.cv_results_
# Out:
# {'param_model__n_neighbors': masked_array(data=[20, 21, 22, ..., 47, 48, 49],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'split0_train_recall': array([0.94405594, 0.95104895, 0.94172494, ..., 0.58508159, 0.63636364,
#         0.63636364]),
#  'split3_test_precision': array([0.56818182, 0.55865922, 0.55813953, ..., 0.77083333, 0.69620253,
#         0.67346939]),
#  'std_fit_time': array([0.29408066, 0.14716501, 0.3117279 , ..., 0.14527536, 0.21711921,
#         0.17835189]),
#  'split1_train_f1': array([0.69342442, 0.69093988, 0.69356223, ..., 0.61601085, 0.60330579,
#         0.60928962]),
#  'split2_test_roc_auc': array([0.67224212, 0.67529915, 0.68141322, ..., 0.68757097, 0.66866102,
#         0.68294174]),
#  'std_test_recall': array([0.01474083, 0.01440207, 0.02486655, ..., 0.14238196, 0.10818229,
#         0.10454819]),
#  'mean_test_precision': array([0.54670715, 0.54263857, 0.54484329, ..., 0.66926822, 0.66175531,
#         0.64885934]),
#  'std_train_average_precision': array([0.0184513 , 0.0186192 , 0.02018544, ..., 0.027226  , 0.01473295,
#         0.00730548]),
#  'mean_test_recall': array([0.93660436, 0.94404638, 0.92542402, ..., 0.51715126, 0.5226722 ,
#         0.52457598]),
#  'split0_train_roc_auc': array([0.75445505, 0.74501667, 0.73889778, ..., 0.74306418, 0.73582064,
#         0.7413949 ]),
#  'split4_test_precision': array([0.56179775, 0.55248619, 0.56179775, ..., 0.58823529, 0.65753425,
#         0.66666667]),
#  'split4_train_f1': array([0.70226244, 0.69572954, 0.69936421, ..., 0.50733138, 0.59799714,
#         0.57263752]),
#  'split4_test_recall': array([0.93457944, 0.93457944, 0.93457944, ..., 0.37383178, 0.44859813,
#         0.46728972]),
#  'std_score_time': array([0.05659991, 0.06011376, 0.14762958, ..., 0.05915143, 0.0594648 ,
#         0.18801814]),
#  'param_feature_union__select_from_model__estimator': masked_array(data=[LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                             solver='svd', store_covariance=False, tol=0.0001),
#                     LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                             solver='svd', store_covariance=False, tol=0.0001),
#                     LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                             solver='svd', store_covariance=False, tol=0.0001),
#                     ...,
#                     LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#            intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#            multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#            verbose=0),
#                     LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#            intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#            multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#            verbose=0),
#                     LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#            intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#            multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#            verbose=0)],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'split1_train_roc_auc': array([0.77137388, 0.76839204, 0.76578056, ..., 0.73529236, 0.73472867,
#         0.74235889]),
#  'split4_train_recall': array([0.9044289 , 0.91142191, 0.8974359 , ..., 0.4032634 , 0.48717949,
#         0.47319347]),
#  'split1_test_f1': array([0.67576792, 0.68013468, 0.67128028, ..., 0.42168675, 0.48192771,
#         0.46341463]),
#  'split3_train_roc_auc': array([0.7342277 , 0.7318804 , 0.73101918, ..., 0.71258307, 0.73073663,
#         0.71827473]),
#  'split0_train_average_precision': array([0.76781861, 0.75856689, 0.75138051, ..., 0.69331133, 0.69658476,
#         0.70637741]),
#  'rank_test_average_precision': array([ 6264,  4910,  4600, ..., 10467, 11794, 12322]),
#  'split3_train_f1': array([0.69754768, 0.69511111, 0.69557362, ..., 0.63532402, 0.59020979,
#         0.65923172]),
#  'mean_train_recall': array([0.92631636, 0.93471015, 0.92491558, ..., 0.5387088 , 0.5582805 ,
#         0.57600048]),
#  'mean_test_f1': array([0.69024789, 0.6890131 , 0.68563151, ..., 0.57822194, 0.57550707,
#         0.57242826]),
#  'mean_train_average_precision': array([0.76389216, 0.76041875, 0.75759172, ..., 0.68699379, 0.70560824,
#         0.69862451]),
#  'rank_test_recall': array([    6,     3,    24, ..., 11313, 10988, 10831]),
#  'split2_train_roc_auc': array([0.77641938, 0.77508544, 0.77618031, ..., 0.74781706, 0.76140371,
#         0.74726284]),
#  'std_train_f1': array([0.00466641, 0.00440741, 0.00390844, ..., 0.05164882, 0.03880856,
#         0.03725706]),
#  'params': [{'model__n_neighbors': 20,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 21,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 22,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 23,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 24,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 25,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 26,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 27,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 28,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 29,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 30,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 31,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 32,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 33,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 34,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 35,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 36,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 37,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 38,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 39,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 40,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 41,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 42,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 43,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 44,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 45,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 46,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 47,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 48,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 49,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                               solver='svd', store_covariance=False, tol=0.0001)},
#   {'model__n_neighbors': 20,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 21,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 22,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 23,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 24,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 25,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 26,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 27,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 28,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 29,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 30,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 31,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 32,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 33,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 34,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 35,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 36,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 37,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 38,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 39,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 40,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 41,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 42,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 43,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 44,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 45,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 46,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 47,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 48,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 49,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': ExtraTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, random_state=None,
#                        splitter='random')},
#   {'model__n_neighbors': 20,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 21,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 22,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 23,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 24,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 25,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 26,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 27,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 28,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 29,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 30,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 31,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 32,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 33,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 34,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 35,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 36,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 37,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 38,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 39,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 40,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 41,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 42,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 43,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 44,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 45,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 46,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 47,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 48,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 49,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 20,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                           criterion='gini', max_depth=None, max_features='auto',
#                           max_leaf_nodes=None, max_samples=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_jobs=None, oob_score=False, random_state=None,
#                           verbose=0, warm_start=False)},
#   {'model__n_neighbors': 21,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                           criterion='gini', max_depth=None, max_features='auto',
#                           max_leaf_nodes=None, max_samples=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_jobs=None, oob_score=False, random_state=None,
#                           verbose=0, warm_start=False)},
#   {'model__n_neighbors': 22,
#    'feature_union__nmf__n_components': 1,
#    'feature_union__select_from_model__estimator': RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                           criterion='gini', max_depth=None, max_features='auto',
#                           max_leaf_nodes=None, max_samples=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_jobs=None, oob_score=False, random_state=None,
# ...
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 46,
#    'feature_union__nmf__n_components': 7,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 47,
#    'feature_union__nmf__n_components': 7,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 48,
#    'feature_union__nmf__n_components': 7,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 49,
#    'feature_union__nmf__n_components': 7,
#    'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                           max_depth=None, max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, presort='deprecated',
#                           random_state=None, splitter='best')},
#   {'model__n_neighbors': 20,
#    'feature_union__nmf__n_components': 7,
#    'feature_union__select_from_model__estimator': RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                           criterion='gini', max_depth=None, max_features='auto',
#                           max_leaf_nodes=None, max_samples=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_jobs=None, oob_score=False, random_state=None,
#                           verbose=0, warm_start=False)},
#   {'model__n_neighbors': 21,
#    'feature_union__nmf__n_components': 7,
#    'feature_union__select_from_model__estimator': RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                           criterion='gini', max_depth=None, max_features='auto',
#                           max_leaf_nodes=None, max_samples=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_jobs=None, oob_score=False, random_state=None,
#                           verbose=0, warm_start=False)},
#   {'model__n_neighbors': 22,
#    'feature_union__nmf__n_components': 7,
#    'feature_union__select_from_model__estimator': RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                           criterion='gini', max_depth=None, max_features='auto',
#                           max_leaf_nodes=None, max_samples=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_jobs=None, oob_score=False, random_state=None,
#                           verbose=0, warm_start=False)},
#   {'model__n_neighbors': 23,
#    'feature_union__nmf__n_components': 7,
#    'feature_union__select_from_model__estimator': RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                           criterion='gini', max_depth=None, max_features='auto',
#                           max_leaf_nodes=None, max_samples=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_jobs=None, oob_score=False, random_state=None,
#                           verbose=0, warm_start=False)},
#   {'model__n_neighbors': 24,
#    'feature_union__nmf__n_components': 7,
#    'feature_union__select_from_model__estimator': RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                           criterion='gini', max_depth=None, max_features='auto',
#                           max_leaf_nodes=None, max_samples=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_jobs=None, oob_score=False, random_state=None,
#                           verbose=0, warm_start=False)},
#   {'model__n_neighbors': 25,
#    'feature_union__nmf__n_components': 7,
#    'feature_union__select_from_model__estimator': RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                           criterion='gini', max_depth=None, max_features='auto',
#                           max_leaf_nodes=None, max_samples=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_jobs=None, oob_score=False, random_state=None,
#                           verbose=0, warm_start=False)},
#   {'model__n_neighbors': 26,
#    'feature_union__nmf__n_components': 7,
#    'feature_union__select_from_model__estimator': RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                           criterion='gini', max_depth=None, max_features='auto',
#                           max_leaf_nodes=None, max_samples=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_jobs=None, oob_score=False, random_state=None,
#                           verbose=0, warm_start=False)},
#   {'model__n_neighbors': 27,
#    'feature_union__nmf__n_components': 7,
#    'feature_union__select_from_model__estimator': RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                           criterion='gini', max_depth=None, max_features='auto',
#                           max_leaf_nodes=None, max_samples=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_jobs=None, oob_score=False, random_state=None,
#                           verbose=0, warm_start=False)},
#   {'model__n_neighbors': 28,
#    'feature_union__nmf__n_components': 7,
#    'feature_union__select_from_model__estimator': RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                           criterion='gini', max_depth=None, max_features='auto',
#                           max_leaf_nodes=None, max_samples=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_jobs=None, oob_score=False, random_state=None,
#                           verbose=0, warm_start=False)},
#   {'model__n_neighbors': 29,
#    'feature_union__nmf__n_components': 7,
#    'feature_union__select_from_model__estimator': RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                           criterion='gini', max_depth=None, max_features='auto',
#                           max_leaf_nodes=None, max_samples=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_jobs=None, oob_score=False, random_state=None,
#                           verbose=0, warm_start=False)},
#   ...],
#  'split1_train_precision': array([0.54643338, 0.54183267, 0.54816825, ..., 0.73462783, 0.73489933,
#         0.73355263]),
#  'split4_test_f1': array([0.70175439, 0.69444444, 0.70175439, ..., 0.45714286, 0.53333333,
#         0.54945055]),
#  'mean_train_roc_auc': array([0.76020895, 0.75628502, 0.75390702, ..., 0.72498597, 0.74114558,
#         0.7374406 ]),
#  'split4_test_roc_auc': array([0.74133112, 0.74259761, 0.73639619, ..., 0.63826535, 0.68136955,
#         0.69023496]),
#  'split0_train_precision': array([0.54144385, 0.53333333, 0.54155496, ..., 0.69722222, 0.67910448,
#         0.69465649]),
#  'split3_test_average_precision': array([0.71478488, 0.71951636, 0.70585159, ..., 0.75176025, 0.69659866,
#         0.68838088]),
#  'std_test_roc_auc': array([0.03384817, 0.03463614, 0.03077765, ..., 0.04897529, 0.02578734,
#         0.02662207]),
#  'rank_test_precision': array([14893, 14943, 14908, ...,  3807,  5353,  7733]),
#  'split3_train_recall': array([0.8951049 , 0.91142191, 0.8974359 , ..., 0.58275058, 0.49184149,
#         0.62004662]),
#  'split0_test_precision': array([0.54210526, 0.5388601 , 0.53926702, ..., 0.68817204, 0.61538462,
#         0.5959596 ]),
#  'split2_train_recall': array([0.93939394, 0.94638695, 0.94405594, ..., 0.59207459, 0.66433566,
#         0.62937063]),
#  'mean_test_average_precision': array([0.66773603, 0.67094357, 0.67179879, ..., 0.65839852, 0.65495789,
#         0.65346801]),
#  'split3_train_average_precision': array([0.72846713, 0.72705198, 0.72333694, ..., 0.66771826, 0.69047554,
#         0.68599183]),
#  'mean_fit_time': array([ 3.29868116,  3.46022806,  3.31784368, ..., 12.95613565,
#         12.8119813 , 12.27954736]),
#  'std_train_recall': array([0.02206993, 0.01914416, 0.02245235, ..., 0.07120807, 0.07613878,
#         0.06636776]),
#  'split0_train_f1': array([0.68819031, 0.68341709, 0.68765957, ..., 0.63624842, 0.65703971,
#         0.66423358]),
#  'split0_test_average_precision': array([0.61865743, 0.62590601, 0.62252648, ..., 0.64270577, 0.60674674,
#         0.63130343]),
#  'split1_train_average_precision': array([0.77396561, 0.77093752, 0.77128712, ..., 0.70986151, 0.6973408 ,
#         0.69597948]),
#  'split3_test_roc_auc': array([0.72403703, 0.72622063, 0.71399249, ..., 0.78504673, 0.73076251,
#         0.72600227]),
#  'mean_train_precision': array([0.55736835, 0.54904729, 0.55645152, ..., 0.7058923 , 0.7283841 ,
#         0.71274382]),
#  'rank_test_f1': array([  239,   276,   408, ..., 11243, 11537, 11848]),
#  'param_feature_union__nmf__n_components': masked_array(data=[1, 1, 1, ..., 100, 100, 100],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'mean_train_f1': array([0.69561082, 0.69148795, 0.69452686, ..., 0.60857477, 0.62755813,
#         0.63424741]),
#  'split1_test_recall': array([0.91666667, 0.93518519, 0.89814815, ..., 0.32407407, 0.37037037,
#         0.35185185]),
#  'split2_test_f1': array([0.67340067, 0.67785235, 0.67567568, ..., 0.64321608, 0.62801932,
#         0.63255814]),
#  'split4_train_precision': array([0.5739645 , 0.56258993, 0.57291667, ..., 0.68379447, 0.77407407,
#         0.725     ]),
#  'split2_train_f1': array([0.69662921, 0.69224211, 0.69647463, ..., 0.64795918, 0.68923821,
#         0.66584464]),
#  'split2_test_recall': array([0.93457944, 0.94392523, 0.93457944, ..., 0.59813084, 0.60747664,
#         0.63551402]),
#  'std_test_average_precision': array([0.03326551, 0.03256683, 0.02899009, ..., 0.05299612, 0.03111603,
#         0.02234726]),
#  'mean_test_roc_auc': array([0.69302915, 0.69409693, 0.69055214, ..., 0.69312677, 0.68195128,
#         0.68250454]),
#  'split2_train_precision': array([0.55357143, 0.54569892, 0.55177112, ..., 0.71549296, 0.7160804 ,
#         0.70680628]),
#  'split1_test_precision': array([0.53513514, 0.53439153, 0.5359116 , ..., 0.60344828, 0.68965517,
#         0.67857143]),
#  'split3_test_f1': array([0.70671378, 0.6993007 , 0.68817204, ..., 0.72906404, 0.59139785,
#         0.64390244]),
#  'split2_test_precision': array([0.52631579, 0.52879581, 0.52910053, ..., 0.69565217, 0.65      ,
#         0.62962963]),
#  'split0_test_recall': array([0.96261682, 0.97196262, 0.96261682, ..., 0.59813084, 0.6728972 ,
#         0.55140187]),
#  'split3_test_recall': array([0.93457944, 0.93457944, 0.89719626, ..., 0.69158879, 0.51401869,
#         0.61682243]),
#  'split1_test_average_precision': array([0.66953778, 0.66835367, 0.67038635, ..., 0.63915129, 0.63733378,
#         0.6283053 ]),
#  'std_train_precision': array([0.01312023, 0.01145213, 0.01194467, ..., 0.01754233, 0.03097687,
#         0.01433423]),
#  'split1_test_roc_auc': array([0.67579612, 0.67640187, 0.67030114, ..., 0.67921426, 0.6556767 ,
#         0.66800796]),
#  'split4_test_average_precision': array([0.68915019, 0.69177979, 0.69551716, ..., 0.59043676, 0.65758221,
#         0.65348641]),
#  'split0_test_roc_auc': array([0.65173936, 0.64996539, 0.65065767, ..., 0.67553652, 0.6732866 ,
#         0.64533576]),
#  'split4_train_average_precision': array([0.76750157, 0.7627458 , 0.75915767, ..., 0.64514188, 0.71231005,
#         0.69995269]),
#  'mean_score_time': array([0.58818259, 0.57017193, 0.64068208, ..., 3.75310988, 3.4190135 ,
#         2.90405245]),
#  'std_test_precision': array([0.01587315, 0.01120312, 0.01282925, ..., 0.06673461, 0.02922759,
#         0.03153959]),
#  'split0_test_f1': array([0.69360269, 0.69333333, 0.69127517, ..., 0.64      , 0.64285714,
#         0.57281553]),
#  'rank_test_roc_auc': array([ 6075,  5626,  7112, ...,  6036, 10518, 10342]),
#  'split3_train_precision': array([0.57142857, 0.56178161, 0.56784661, ..., 0.69832402, 0.73776224,
#         0.7037037 ]),
#  'split2_test_average_precision': array([0.64654985, 0.64916199, 0.66471238, ..., 0.66793853, 0.67652807,
#         0.66586402]),
#  'std_train_roc_auc': array([0.01493034, 0.01578168, 0.01673484, ..., 0.0228673 , 0.01087982,
#         0.01003847]),
#  'split2_train_average_precision': array([0.78170788, 0.78279155, 0.78279636, ..., 0.71893596, 0.73133007,
#         0.70482114]),
#  'split4_train_roc_auc': array([0.76456876, 0.76105053, 0.75765726, ..., 0.68617319, 0.74303824,
#         0.73791166]),
#  'std_test_f1': array([0.01347797, 0.00845443, 0.0109848 , ..., 0.11828569, 0.06013619,
#         0.06501732]),
#  'split1_train_recall': array([0.94859813, 0.95327103, 0.94392523, ..., 0.53037383, 0.51168224,
#         0.52102804])}

# %%
grid.best_score_
# Out:
# 0.7136819382690869

# %%
mean_test = []
mean_train = []
mean_other = []
for x in grid.cv_results_.keys():
    if "mean_test" in x:
        mean_test.append(x)
    if "mean_train" in x :
        mean_train.append(x)
    if "mean" in x:
        mean_other.append(x)

# %%
custom_index = 0
custom_index_of = "test_average_precision"
custom_index_of = "test_precision"
custom_index_of = "f1"
for x in mean_test:
    res = grid.cv_results_[x]
    max_index = list(res).index(max(res))
    if custom_index_of in x:
        custom_index = max_index
# custom_index = 11000
for x in mean_test:
    res = grid.cv_results_[x]
    max_index = list(res).index(max(res))
    print(x,"\t",res,'\t',max(res),'\n Max Index ::',max_index)
    print("Custom Index ::: ",custom_index," out of ",len(list(res))," :::: ",list(res)[custom_index])
    print("----------"*12)
    print("----------"*12)
# Out:
# mean_test_precision 	 [0.54670715 0.54263857 0.54484329 ... 0.66926822 0.66175531 0.64885934] 	 0.7412384250191612
#  Max Index :: 12823
# Custom Index :::  364  out of  15000  ::::  0.6340522826110662
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# mean_test_recall 	 [0.93660436 0.94404638 0.92542402 ... 0.51715126 0.5226722  0.52457598] 	 0.945932848736587
#  Max Index :: 91
# Custom Index :::  364  out of  15000  ::::  0.8173070266528211
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# mean_test_f1 	 [0.69024789 0.6890131  0.68563151 ... 0.57822194 0.57550707 0.57242826] 	 0.7136819382690869
#  Max Index :: 364
# Custom Index :::  364  out of  15000  ::::  0.7136819382690869
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# mean_test_average_precision 	 [0.66773603 0.67094357 0.67179879 ... 0.65839852 0.65495789 0.65346801] 	 0.7442166459882611
#  Max Index :: 217
# Custom Index :::  364  out of  15000  ::::  0.7308233299144343
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# mean_test_roc_auc 	 [0.69302915 0.69409693 0.69055214 ... 0.69312677 0.68195128 0.68250454] 	 0.7523851347198365
#  Max Index :: 368
# Custom Index :::  364  out of  15000  ::::  0.7497630393079777
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------

# %%
grid.cv_results_['param_feature_union__select_from_model__estimator'][364]
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
grid.cv_results_['params'][364]
# Out:
# {'model__n_neighbors': 24,
#  'feature_union__nmf__n_components': 3,
#  'feature_union__select_from_model__estimator': DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                         max_depth=None, max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort='deprecated',
#                         random_state=None, splitter='best')}
