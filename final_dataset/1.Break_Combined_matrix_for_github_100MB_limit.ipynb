# %%
import pandas as pd
import numpy as np

# %%
series = pd.read_csv("combined_matrix_final.csv")

# %%
(series.shape[0]/3)*3
# Out:
# 22215.0

# %%
rows_per_file = int(series.shape[0]/3)

# %%
series1 = series[:rows_per_file]
series2 = series[rows_per_file:2*rows_per_file]
series3 = series[2*rows_per_file:3*rows_per_file]

# %%
series1.to_csv("combined_matrix_final_1.csv",index=False)
series2.to_csv("combined_matrix_final_2.csv",index=False)
series3.to_csv("combined_matrix_final_3.csv",index=False)

# %%
series3[:]
# Out:
#             ID_REF  GSM107072  GSM107073  GSM107074  GSM107075  GSM107076  \
# 14810  215437_x_at   4.540362   4.321610   5.151508   4.370563   5.236832
# 14811  215438_x_at   7.881964   8.425861   8.176763   7.559307   7.536295
# 14812  215439_x_at   6.041571   5.645204   5.728851   6.018644   5.705083
# 14813  215440_s_at   7.110231   7.041704   7.088737   7.323881   7.225114
# 14814    215441_at   3.943546   4.185445   4.736040   4.176825   0.968884
# 14815  215442_s_at   5.249247   2.855528   2.051520   3.168259   2.655283
# 14816    215443_at   3.638507   4.571986   3.108584   3.009002   2.542695
# 14817  215444_s_at   4.011978   5.048313   4.281785   3.868326   3.716155
# 14818  215445_x_at   5.050129   5.824493   5.377894   4.676648   5.359313
# 14819  215446_s_at   8.388172   7.269675   5.052761   7.238140   7.447394
# 14820    215447_at   5.619171   5.336829   5.312297   5.837991   5.031050
# 14821    215448_at   4.029756   3.915761   5.546265   5.200055   4.705363
# ...
