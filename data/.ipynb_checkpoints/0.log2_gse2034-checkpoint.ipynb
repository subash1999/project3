# %%
import pandas as pd
import numpy as np
import math
import sys
sys.path.append('../')

# %%
df = pd.read_csv("data/series_matrix/gse2034_series_matrix.csv")

# %%
df.head()
# Out:
#       ID_REF  GSM36777  GSM36778  GSM36779  GSM36780  GSM36781  GSM36782  \
# 0  1007_s_at    3848.1    6520.9    5285.7    4043.7    4263.6    2949.8
# 1    1053_at     228.9     112.5     178.4     398.7     417.7     221.2
# 2     117_at     213.1     189.8     269.7     312.4     327.1     225.0
# 3     121_at    1009.4    2083.3    1203.4    1104.4    1043.3    1117.6
# 4  1255_g_at      31.8     145.8      42.5     108.2      69.2      47.4
#
#    GSM36783  GSM36784  GSM36785  ...  GSM37053  GSM37054  GSM37055  GSM37056  \
# 0    5498.9    3863.1    3370.4  ...    4058.2    4017.6    2841.0    2914.2
# 1     280.4     198.2     304.7  ...     183.4     356.1     234.6     169.4
# 2     243.5     244.4     348.5  ...     326.6     234.9     369.6     149.5
# 3    1085.4    1423.1    1196.4  ...    1041.3    1195.6     751.5    1117.8
# 4      84.3     102.0      22.8  ...     143.5      32.7      62.6      43.0
#
#    GSM37057  GSM37058  GSM37059  GSM37060  GSM37061  GSM37062
# ...

# %%
for x in df.columns[1:]:
    list_  = []
    for y in list(df[x]):
        list_.append(math.log2(float(y)))
    df[x] = list_
df.head()
# Out:
#       ID_REF   GSM36777   GSM36778   GSM36779   GSM36780   GSM36781  \
# 0  1007_s_at  11.909931  12.670855  12.367879  11.981460  12.057856
# 1    1053_at   7.838574   6.813781   7.478972   8.639160   8.706323
# 2     117_at   7.735387   7.568336   8.075212   8.287251   8.353588
# 3     121_at   9.979282  11.024655  10.232901  10.109047  10.026938
# 4  1255_g_at   4.990955   7.187847   5.409391   6.757557   6.112700
#
#     GSM36782   GSM36783   GSM36784   GSM36785  ...   GSM37053   GSM37054  \
# 0  11.526401  12.424927  11.915543  11.718704  ...  11.986624  11.972118
# 1   7.789208   8.131343   7.630813   8.251246  ...   7.518850   8.476139
# 2   7.813781   7.927778   7.933100   8.445015  ...   8.351381   7.875903
# 3  10.126188  10.084011  10.474821  10.224484  ...  10.024170  10.223519
# 4   5.566815   6.397461   6.672425   4.510962  ...   7.164907   5.031219
#
#     GSM37055   GSM37056   GSM37057   GSM37058   GSM37059   GSM37060  \
# ...

# %%
df.to_csv("data/series_matrix/gse2034_series_matrix_log2.csv")
